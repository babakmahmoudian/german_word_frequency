# %%
import pandas as pd

from configs import (
    FREQDICT_FILE, ANKIFREQ_FILE,
    RANK_COL, LEMMA_COL, FREQUENCY_COL, POS_COL, WORD_COL,
    MAX_RANK_TO_ADD, MAX_RANK_TO_KEEP,
    ANKI_WORD_FIELD, ANKI_NOTETYPE_COL,
    ANKI_REPORT_PATH, ANKI_TO_KEEP_FILE_PREFIX, ANKI_TO_ADD_FILE_PREFIX,
    ANKI_FLAG_COL, ANKI_FLAG_VALUE
)

# %%
df_freqs = pd.read_csv(FREQDICT_FILE)

df_freqs
# Out:
#              word  frequency     lemma  \
# 0             die    1900392       der
# 1             der    1696311       der
# 2             und    1415926       und
# 3              in     925244        in
# 4             das     662237       der
# ...           ...        ...       ...
# 1152561    aaalen          1    aaalen
# 1152562     aaahs          1      aaah
# 1152563  aaahhhhh          1  aaahhhhh
# 1152564     aaahh          1     aaahh
# 1152565      aaah          1      aaah
#
#                                                      morph    pos    rank
# 0        Case=Nom|Definite=Def|Gender=Fem|Number=Sing|P...    DET       1
# 1        Case=Nom|Definite=Def|Gender=Masc|Number=Sing|...    DET       2
# 2                                                      NaN  CCONJ       3
# 3                                                      NaN    ADP       4
# 4        Case=Nom|Definite=Def|Gender=Neut|Number=Sing|...    DET       5
# ...                                                    ...    ...     ...
# 1152561                                       VerbForm=Inf   VERB  497920
# 1152562                   Case=Gen|Gender=Masc|Number=Sing  PROPN  497920
# 1152563  Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbF...   VERB  497920
# 1152564                    Case=Nom|Gender=Fem|Number=Sing   NOUN  497920
# 1152565                   Case=Nom|Gender=Neut|Number=Sing  PROPN  497920
#
# [1152566 rows x 6 columns]

# %%
df_anki = pd.read_csv(ANKIFREQ_FILE)

df_anki
# Out:
#                            notetype                          Deutsch  \
# 0                    My-German-Noun                 der Familienname
# 1                    My-German-Noun                        die Frage
# 2                    My-German-Noun                         das Land
# 3     My-German-PragmaticExpression  Mir geht's gut, danke! Und dir?
# 4             My-German-Preposition                               in
# ...                             ...                              ...
# 2622                 My-German-Noun                          der Ski
# 2623                 My-German-Noun                     die Vetterin
# 2624  My-German-PragmaticExpression                         O là là!
# 2625               My-German-Adverb                          dorther
# 2626                 My-German-Noun                   die Parfumerie
#
#             word       lemma  frequency  rank
# 0            der         der    1900392     1
# 1            die         der    1900392     1
# 2            das         der    1900392     1
# 3            und         und    1415926     3
# 4             in          in     925244     4
# ...          ...         ...        ...   ...
# 2622         ski          --          0     0
# 2623    vetterin    vetterin          0     0
# 2624          là          là          0     0
# 2625     dorther     dorther          0     0
# 2626  parfumerie  parfumerie          0     0
#
# [2627 rows x 6 columns]

# %% [markdown]
# # Filtering the top ranking lemmas

# %%
df_top_lemmas = df_freqs[(df_freqs[RANK_COL] <= MAX_RANK_TO_ADD) & (df_freqs[FREQUENCY_COL] > 0)]
anki_lemmas = df_anki[LEMMA_COL].unique()
anki_lemmas_in_top = df_anki[(df_anki[RANK_COL] <= MAX_RANK_TO_ADD) & (df_anki[FREQUENCY_COL] > 0)][LEMMA_COL].unique()
anki_lemmas_in_acceptable = df_anki[(df_anki[RANK_COL] <= MAX_RANK_TO_KEEP) & (df_anki[RANK_COL] > MAX_RANK_TO_ADD)][LEMMA_COL].unique()
anki_lemmas_to_keep = df_anki[(df_anki[RANK_COL] <= MAX_RANK_TO_KEEP) & (df_anki[FREQUENCY_COL] > 0)][LEMMA_COL].unique()
# top_lemmas_missing_in_anki = set(top_lemmas[LEMMA_COL].unique()) - set(anki_lemmas_to_keep)

# %%
print("Summary of lemma comparison between Anki and top frequency list:")
print(f"Optiomal rank: {MAX_RANK_TO_ADD}")
print(f"Acceptable rank: {MAX_RANK_TO_KEEP}")
print(f"Total top lemmas: {df_top_lemmas[LEMMA_COL].nunique()}")
print(f"Total Anki lemmas: {len(anki_lemmas)}")
print(f"Total Anki lemmas of optimal rank: {len(anki_lemmas_in_top)}")
print(f"Total Anki lemmas of acceptable rank: {len(anki_lemmas_in_acceptable)}")
# Out:
# Summary of lemma comparison between Anki and top frequency list:
# Optiomal rank: 5000
# Acceptable rank: 10000
# Total top lemmas: 3440
# Total Anki lemmas: 2551
# Total Anki lemmas of optimal rank: 1338
# Total Anki lemmas of acceptable rank: 413

# %%
anki_keep = df_anki[df_anki[LEMMA_COL].isin(anki_lemmas_to_keep)]
anki_add = df_top_lemmas[~df_top_lemmas[LEMMA_COL].isin(anki_lemmas)]

# %% [markdown]
# # Lemmas to keep

# %%
anki_keep = anki_keep[[ANKI_NOTETYPE_COL, ANKI_WORD_FIELD, LEMMA_COL, RANK_COL]].sort_values(by=[ANKI_NOTETYPE_COL, ANKI_WORD_FIELD])

print(f"Total Anki lemmas to keep: {len(anki_lemmas_to_keep)}")
anki_keep
# Out:
# Total Anki lemmas to keep: 1751
#                  notetype       Deutsch         lemma  rank
# 658   My-German-Adjective     allgemein     allgemein  1262
# 360   My-German-Adjective           alt           alt   560
# 23    My-German-Adjective     am besten            an    24
# 88    My-German-Adjective     am besten           gut   119
# 1054  My-German-Adjective  amerikanisch  amerikanisch  2808
# ...                   ...           ...           ...   ...
# 710        My-German-Verb        öffnen        öffnen  1432
# 1224       My-German-Verb          üben          üben  3771
# 1174       My-German-Verb     überlegen     überlegen  3448
# 1792       My-German-Verb    überqueren    überqueren  9453
# 1486       My-German-Verb    übersetzen    übersetzen  5616
#
# [1824 rows x 4 columns]

# %% [markdown]
# ## Exporting the output

# %%
postypes = anki_keep[ANKI_NOTETYPE_COL].unique()

for pos in postypes:
    report_file = f"{ANKI_REPORT_PATH}/{ANKI_TO_KEEP_FILE_PREFIX}{pos.replace("-", "_")}.csv" 
    df_tosave = anki_keep[anki_keep[ANKI_NOTETYPE_COL] == pos][[ANKI_WORD_FIELD]]
    df_tosave[ANKI_FLAG_COL] = ANKI_FLAG_VALUE
    df_tosave.to_csv(report_file, index=False, header=None)

# %% [markdown]
# # Lemmas to add

# %%
anki_add.groupby(POS_COL)[LEMMA_COL].nunique()
# Out:
# pos
# ADJ      190
# ADP       26
# ADV      305
# AUX        9
# CCONJ      5
# DET       13
# NOUN     931
# NUM       14
# PART       2
# PRON      36
# PROPN    259
# SCONJ      7
# VERB     338
# X         66
# Name: lemma, dtype: int64

# %%
def filter_by_pos(df, pos):
    return df[df[POS_COL] == pos].sort_values(by=WORD_COL)

def filter_by_single_pos(df, pos):
    df_local = df.copy()
    df_local['POS_count'] = df_local.groupby(LEMMA_COL)[POS_COL].transform('nunique')
    return df_local[(df_local[POS_COL] == pos) & (df_local['POS_count'] == 1)].sort_values(by=WORD_COL)

# %% [markdown]
# ### Pos: X

# %%
filter_by_single_pos(anki_add, 'X')
# Out:
#           word  frequency     lemma        morph pos  rank  POS_count
# 4453       big        977       big  Foreign=Yes   X  4453          1
# 2688  business       1763  business  Foreign=Yes   X  2687          1
# 2520    campus       1892    campus  Foreign=Yes   X  2520          1
# 4257   caritas       1033   caritas  Foreign=Yes   X  4254          1
# 1906        cm       2526        cm          NaN   X  1907          1
# ...        ...        ...       ...          ...  ..   ...        ...
# 2327   windows       2054   windows  Foreign=Yes   X  2328          1
# 4155        wm       1067        wm          NaN   X  4154          1
# 1640         x       2916         x          NaN   X  1641          1
# 2045         z       2358         z          NaN   X  2046          1
# 3411       övp       1335       övp          NaN   X  3411          1
#
# [65 rows x 7 columns]

# %%
# Remove all the instances with pos 'X' from anki_add
anki_add = anki_add[anki_add[POS_COL] != 'X']

# %% [markdown]
# ## Pos: SCONJ

# %%
filter_by_single_pos(anki_add, 'SCONJ')
# Out:
#          word  frequency    lemma         morph    pos  rank  POS_count
# 4462  anstatt        976  anstatt           NaN  SCONJ  4458          1
# 2679      daß       1768      daß           NaN  SCONJ  2678          1
# 1312   sofern       3635   sofern           NaN  SCONJ  1313          1
# 353     warum      11973    warum  PronType=Int  SCONJ   354          1
# 200        wo      20666       wo  PronType=Int  SCONJ   201          1
# 4006    woher       1111    woher  PronType=Int  SCONJ  4005          1
# 3382   worauf       1346   worauf  PronType=Int  SCONJ  3381          1

# %% [markdown]
# ## Pos: AUX

# %%
filter_by_single_pos(anki_add, 'AUX')
# Out:
#           word  frequency     lemma  \
# 3771       hab       1182       hab
# 607     kannst       7289  könnsten
# 99        muss      45426    mussen
# 3074     musst       1515     musst
# 497     musste       8908    musste
# 981    mussten       4670   mussten
# 3492  möchtest       1299  möchtest
# 2908  solltest       1609  solltest
# 3962     wirst       1122   wersten
#
#                                                   morph  pos  rank  POS_count
# 3771  Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbF...  AUX  3771          1
# 607   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...  AUX   608          1
# 99    Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...  AUX   100          1
# 3074  Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbF...  AUX  3074          1
# 497   Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbF...  AUX   498          1
# 981   Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbF...  AUX   982          1
# 3492  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...  AUX  3492          1
# 2908  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...  AUX  2908          1
# 3962  Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbF...  AUX  3963          1

# %%
# Remove all the instances with pos 'AUX' from anki_add
anki_add = anki_add[anki_add[POS_COL] != 'AUX']

# %% [markdown]
# ## Pos: DET

# %%
filter_by_single_pos(anki_add, 'DET')
# Out:
#            word  frequency      lemma  \
# 860         all       5231        all
# 1089       dein       4254       dein
# 664       deine       6696       dein
# 2477     deinem       1923       dein
# 1803     deinen       2668       dein
# 1812     deiner       2655       dein
# 3995       euer       1114       euer
# 1925       eure       2508       eure
# 2894       jene       1622      jener
# 3006  keinerlei       1551  keinerlei
# 428        mein      10133       mein
# 340       meine      12405       mein
# 1277     meinem       3725       mein
# 785      meiner       5720       mein
# 3734     meines       1195     meiner
# 262       unser      16429      unser
# 131      unsere      32648      unser
# 438     unserem       9845      unser
# 329     unseren      12776      unser
# 189     unserer      22400      unser
# 1069    unseres       4326      unser
#
#                                                   morph  pos  rank  POS_count
# 860                                        PronType=Ind  DET   861          1
# 1089  Case=Nom|Gender=Neut|Number=Sing|Poss=Yes|Pron...  DET  1090          1
# 664   Case=Nom|Gender=Fem|Number=Sing|Poss=Yes|PronT...  DET   665          1
# 2477  Case=Dat|Gender=Masc|Number=Sing|Poss=Yes|Pron...  DET  2478          1
# 1803  Case=Acc|Gender=Masc|Number=Sing|Poss=Yes|Pron...  DET  1803          1
# 1812  Case=Dat|Gender=Fem|Number=Sing|Poss=Yes|PronT...  DET  1813          1
# 3995  Case=Nom|Gender=Masc|Number=Sing|Poss=Yes|Pron...  DET  3995          1
# 1925  Case=Nom|Gender=Fem|Number=Sing|Poss=Yes|PronT...  DET  1926          1
# 2894       Case=Nom|Gender=Fem|Number=Sing|PronType=Dem  DET  2893          1
# 3006                                       PronType=Ind  DET  3004          1
# 428   Case=Nom|Gender=Neut|Number=Sing|Poss=Yes|Pron...  DET   429          1
# 340   Case=Nom|Gender=Fem|Number=Sing|Poss=Yes|PronT...  DET   341          1
# 1277  Case=Dat|Gender=Masc|Number=Sing|Poss=Yes|Pron...  DET  1277          1
# 785   Case=Dat|Gender=Fem|Number=Sing|Poss=Yes|PronT...  DET   786          1
# 3734  Case=Gen|Gender=Neut|Number=Sing|Poss=Yes|Pron...  DET  3732          1
# 262   Case=Nom|Gender=Neut|Number=Sing|Poss=Yes|Pron...  DET   263          1
# 131   Case=Nom|Gender=Fem|Number=Sing|Poss=Yes|PronT...  DET   132          1
# 438   Case=Dat|Gender=Neut|Number=Sing|Poss=Yes|Pron...  DET   439          1
# 329   Case=Acc|Gender=Masc|Number=Sing|Poss=Yes|Pron...  DET   330          1
# 189   Case=Dat|Gender=Fem|Number=Sing|Poss=Yes|PronT...  DET   190          1
# 1069  Case=Gen|Gender=Masc|Number=Sing|Poss=Yes|Pron...  DET  1070          1

# %%
ids_to_keep = [3006]

# Remove all the lemmas of instances with pos 'DET' from anki_add, if lemma is not in lemmas_to_keep
anki_add = anki_add[
    (~anki_add[LEMMA_COL].isin(filter_by_pos(anki_add, 'DET')[LEMMA_COL].unique())) | (anki_add.index.isin(ids_to_keep))]

# %% [markdown]
# ## Pos: ADP

# %%
filter_by_single_pos(anki_add, 'ADP')
# Out:
#                 word  frequency           lemma morph  pos  rank  POS_count
# 1348      angesichts       3535      angesichts   NaN  ADP  1349          1
# 1247          anhand       3814          anhand   NaN  ADP  1248          1
# 2659      anlässlich       1785      anlässlich   NaN  ADP  2660          1
# 346         aufgrund      12206        aufgrund   NaN  ADP   347          1
# 3168       bezüglich       1463       bezüglich   NaN  ADP  3167          1
# 4383          binnen       1000          binnen   NaN  ADP  4383          1
# 2224  einschließlich       2159  einschließlich   NaN  ADP  2225          1
# 1632        entgegen       2931        entgegen   NaN  ADP  1632          1
# 1688         entlang       2836         entlang   NaN  ADP  1688          1
# 1972    hinsichtlich       2440    hinsichtlich   NaN  ADP  1972          1
# 472           hinter       9304          hinter   NaN  ADP   473          1
# 2412          hinweg       1978          hinweg   NaN  ADP  2413          1
# 4772         infolge        908         infolge   NaN  ADP  4768          1
# 350        innerhalb      12100       innerhalb   NaN  ADP   351          1
# 2839           minus       1656           minus   NaN  ADP  2839          1
# 1755        mithilfe       2719        mithilfe   NaN  ADP  1756          1
# 3884          namens       1146          namens   NaN  ADP  3884          1
# 328              per      12784             per   NaN  ADP   329          1
# 3520         seitens       1288         seitens   NaN  ADP  3520          1
# 4293       unterhalb       1021       unterhalb   NaN  ADP  4293          1
# 2918             via       1601             via   NaN  ADP  2918          1
# 4088           wider       1085           wider   NaN  ADP  4088          1
# 3804          willen       1174           wille   NaN  ADP  3801          1
# 1026         zufolge       4468         zufolge   NaN  ADP  1025          1
# 4660       zugunsten        933       zugunsten   NaN  ADP  4659          1

# %% [markdown]
# ## Pos: NUM

# %%
filter_by_single_pos(anki_add, 'NUM')
# Out:
#         word  frequency   lemma morph  pos  rank  POS_count
# 669     acht       6651    acht   NaN  NUM   670          1
# 128     drei      33778    drei   NaN  NUM   129          1
# 1684     elf       2844     elf   NaN  NUM  1684          1
# 286     fünf      14765    fünf   NaN  NUM   287          1
# 1173    neun       4011    neun   NaN  NUM  1174          1
# 419    sechs      10308   sechs   NaN  NUM   420          1
# 675   sieben       6601  sieben   NaN  NUM   676          1
# 217     vier      18639    vier   NaN  NUM   218          1
# 389     zehn      10895    zehn   NaN  NUM   390          1
# 92      zwei      48622    zwei   NaN  NUM    93          1
# 1212   zwölf       3913   zwölf   NaN  NUM  1213          1

# %%
filter_by_pos(anki_add, 'NUM')
# Out:
#          word  frequency    lemma morph  pos  rank
# 669      acht       6651     acht   NaN  NUM   670
# 128      drei      33778     drei   NaN  NUM   129
# 1684      elf       2844      elf   NaN  NUM  1684
# 286      fünf      14765     fünf   NaN  NUM   287
# 3860   halben       1153     halb   NaN  NUM  3861
# 3079  hundert       1510  hundert   NaN  NUM  3080
# 1173     neun       4011     neun   NaN  NUM  1174
# 419     sechs      10308    sechs   NaN  NUM   420
# 675    sieben       6601   sieben   NaN  NUM   676
# 4198  tausend       1051  tausend   NaN  NUM  4196
# 217      vier      18639     vier   NaN  NUM   218
# 389      zehn      10895     zehn   NaN  NUM   390
# 92       zwei      48622     zwei   NaN  NUM    93
# 1212    zwölf       3913    zwölf   NaN  NUM  1213

# %%
# Remove all the lemmas of instances with pos 'NUM' from anki_add, regardless of their pos
anki_add = anki_add[~anki_add[LEMMA_COL].isin(filter_by_pos(anki_add, 'NUM')[LEMMA_COL].unique())]

# %% [markdown]
# ## Pos: PART

# %%
filter_by_single_pos(anki_add, 'PART').sort_values(by=LEMMA_COL)
# Out:
#        word  frequency  lemma morph   pos  rank  POS_count
# 4555  allzu        953  allzu   NaN  PART  4555          1
# 1709   nein       2786   nein   NaN  PART  1710          1

# %% [markdown]
# ## Pos: PRON

# %%
filter_by_single_pos(anki_add, 'PRON').sort_values(by=LEMMA_COL)
# Out:
#             word  frequency       lemma  \
# 3008  diejenigen       1547   derjenige
# 425         dich      10177        dich
# 2044        eins       2360       einer
# 38            er     157523          er
# 4562     etliche        951    etlicher
# 470         euch       9335        euch
# 4149  hessischen       1068    hessisch
# 248          ihm      17166         ihm
# 211          ihn      19477         ihn
# 111        ihnen      39439       ihnen
# 1780       infos       2694       infos
# 4160   jüdischen       1065     jüdisch
# 1597      keiner       2987      keiner
# 4680    mehrerer        928     mehrere
# 791     mehreren       5691     mehrere
# 306      mehrere      13903     mehrere
# 2682           s       1766           s
# 16          sich     363357        sich
# 1997   sämtliche       2416  sämtlicher
# 73           uns      57945         uns
# 1715      vieles       2783       viele
# 1124    weiteres       4128    weiterer
# 3945         wem       1127         wem
# 3313         wen       1382         wen
# 850       wenige       5288     weniger
# 1081     wenigen       4289     weniger
# 314      weniger      13491     weniger
# 146          wer      29117         wer
# 33           wir     176649         wir
#
#                                                   morph   pos  rank  POS_count
# 3008                  Case=Nom|Number=Plur|PronType=Dem  PRON  3008          1
# 425   Case=Acc|Number=Sing|Person=2|PronType=Prs|Ref...  PRON   426          1
# 2044      Case=Nom|Gender=Neut|Number=Sing|PronType=Ind  PRON  2045          1
# 38    Case=Nom|Gender=Masc|Number=Sing|Person=3|Pron...  PRON    39          1
# 4562                  Case=Nom|Number=Plur|PronType=Ind  PRON  4562          1
# 470          Case=Dat|Number=Plur|Person=2|PronType=Prs  PRON   471          1
# 4149                              Case=Gen|PronType=Dem  PRON  4150          1
# 248   Case=Dat|Gender=Masc|Number=Sing|Person=3|Pron...  PRON   249          1
# 211   Case=Acc|Gender=Masc|Number=Sing|Person=3|Pron...  PRON   212          1
# 111          Case=Dat|Number=Plur|Person=3|PronType=Prs  PRON   112          1
# 1780         Case=Nom|Number=Plur|Person=1|PronType=Prs  PRON  1780          1
# 4160                              Case=Gen|PronType=Dem  PRON  4161          1
# 1597      Case=Nom|Gender=Masc|Number=Sing|PronType=Ind  PRON  1596          1
# 4680      Case=Nom|Gender=Masc|Number=Sing|PronType=Ind  PRON  4680          1
# 791       Case=Dat|Gender=Neut|Number=Plur|PronType=Ind  PRON   792          1
# 306                   Case=Nom|Number=Plur|PronType=Ind  PRON   307          1
# 2682  Case=Nom|Gender=Neut|Number=Sing|Person=3|Pron...  PRON  2683          1
# 16    Case=Acc|Number=Sing|Person=3|PronType=Prs|Ref...  PRON    17          1
# 1997                  Case=Nom|Number=Plur|PronType=Ind  PRON  1997          1
# 73           Case=Acc|Number=Plur|Person=1|PronType=Prs  PRON    74          1
# 1715      Case=Nom|Gender=Neut|Number=Sing|PronType=Ind  PRON  1716          1
# 1124      Case=Nom|Gender=Neut|Number=Sing|PronType=Ind  PRON  1125          1
# 3945      Case=Dat|Gender=Masc|Number=Sing|PronType=Int  PRON  3946          1
# 3313      Case=Acc|Gender=Masc|Number=Sing|PronType=Int  PRON  3314          1
# 850                   Case=Nom|Number=Plur|PronType=Ind  PRON   851          1
# 1081                  Case=Nom|Number=Plur|PronType=Ind  PRON  1082          1
# 314                                        PronType=Ind  PRON   315          1
# 146       Case=Nom|Gender=Masc|Number=Sing|PronType=Int  PRON   147          1
# 33           Case=Nom|Number=Plur|Person=1|PronType=Prs  PRON    34          1

# %%
ids_to_keep = [3008, 4562, 4680, 791, 306, 1997, 1715, 3945, 3313, 850, 1081, 314, 146, 33]

# Remove all the lemmas of instances with pos 'PRON' from anki_add, if lemma is not in lemmas_to_keep
anki_add = anki_add[
    (~anki_add[LEMMA_COL].isin(filter_by_pos(anki_add, 'PRON')[LEMMA_COL].unique())) | (anki_add.index.isin(ids_to_keep))]

# %% [markdown]
# ## Exporting the output

# %%
postypes = anki_add[POS_COL].unique()

for pos in postypes:
    report_file = f"{ANKI_REPORT_PATH}/{ANKI_TO_ADD_FILE_PREFIX}{pos}.csv" 
    df_tosave = anki_add[anki_add[POS_COL] == pos].drop(columns=[POS_COL])
    df_tosave.to_csv(report_file, index=False)
