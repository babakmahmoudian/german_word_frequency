# %%
from more_itertools import chunked
import pandas as pd

INPUT_FILE_PREFIX = './data/reports/anki_to_add_'
INPUT_FILE_TITLE = 'VERB'
TEMP_FILE = f"./data/reports/{INPUT_FILE_TITLE}_temp.csv"
OUTPUT_FILE = f"./data/reports/{INPUT_FILE_TITLE}.csv"
MODIFIER_FILE = f"./data/reports/possible_modifier.csv"
WORD = 'word'
LEMMA = 'lemma'
IS_HIGHFREQUENCY = 'is_highfrequency'
IS_HIGHFREQUENCY_VALUE = 'Yes'
BATCH_SIZE = 30

# %%
# Prints the list in batches so each can be processed manually by outside tools (AI, ...)
def print_in_batches(df):
    for batch in chunked(df[WORD].tolist(), BATCH_SIZE):
        print(', '.join(batch),'\n')

# %%
# Deletes the given rows from the given dataframe
def drop_rows(dest_df, to_drop):
    expected_length = len(dest_df) - len(to_drop)
    dest_df = dest_df.drop(to_drop.index, axis='index')
    assert len(dest_df) == expected_length
    return dest_df

# %%
# Adds the given rows to the given dataframe
def add_rows(dest_df, to_add):
    expected_length = len(dest_df) + len(to_add)
    dest_df = pd.concat([dest_df, to_add], ignore_index=True)
    assert len(dest_df) == expected_length
    return dest_df

# %%
# Looks up a list of words or lemmas in a dataframe
def get_rows(to_find, in_list):
    return to_find[to_find.isin(in_list.unique())]

# %% [markdown]
# # Input

# %%
df = pd.read_csv(
    f"{INPUT_FILE_PREFIX}{INPUT_FILE_TITLE}.csv", 
    sep=",", header=1, index_col=None,
    usecols=[0, 2], names=[WORD, LEMMA]
).sort_values(by=[LEMMA, WORD])

df.sample(20)
# Out:
#                 word            lemma
# 477           genügt          genügen
# 113          gelingt         gelingen
# 207        erfordert        erfordern
# 376  veröffentlichte  veröffentlichen
# 223         umsetzen         umsetzen
# 491       besprochen       besprechen
# 399        hinweisen        hinweisen
# 33       aufgenommen        aufnehmen
# 29          befinden         befinden
# 429          wurzeln           wurzel
# 331       engagierte       engagieren
# 77           betonte          betonen
# 366           befand         befinden
# 212        ausgebaut         ausbauen
# 486      ausgebildet        ausbilden
# 144           sorgte           sorgen
# 289          erkennt         erkennen
# 493        zustimmen        zustimmen
# 221             wies           weisen
# 364           leidet           leiden

# %% [markdown]
# # Process

# %%
# This will contain the final list of verbs to be added into Anki.
df_results = pd.DataFrame(columns=df.columns)

# This will contain the instances where the word was rather more of an adj or adv instead of a verb.
df_modifiers = pd.DataFrame(columns=df.columns)

# %% [markdown]
# ## Duplicate words: simply drop

# %%
df[df.duplicated([WORD], keep=False)]
# Out:
# Empty DataFrame
# Columns: [word, lemma]
# Index: []

# %% [markdown]
# ## words with separable prefix still attatched
# These are either adj/adv or they could be verbs in infinitive form

# %%
separable_prefixes = ('ab','an','auf','aus','bei','ein','fest','fort','her','hin','mit','nach','vor','weg','zu','zurück','zusammen','durch','über','unter','um','wider','wieder')
df_separable_perfixed_words = df[df[WORD].str.startswith(separable_prefixes)]

# Removing them from the primary list
df = drop_rows(df, df_separable_perfixed_words)

df_separable_perfixed_words.sample(10)
# Out:
#               word         lemma
# 66      vorgesehen      vorsehen
# 163    aufgestellt    aufstellen
# 246      vorgelegt      vorlegen
# 300   ausgerichtet    ausrichten
# 123      angepasst      anpassen
# 395    ausgestellt    ausstellen
# 381     angebracht     anbringen
# 294  untergebracht  unterbringen
# 143     eingeführt     einführen
# 447   hinterlassen  hinterlassen

# %% [markdown]
# These cases will be throughly processed and filtered; hence, any other occurances of these lemmas can be safely deleted from the primary list.

# %%
pd.concat([
    get_rows(df[WORD], df_separable_perfixed_words[LEMMA]),
    get_rows(df[LEMMA], df_separable_perfixed_words[WORD]),
    get_rows(df[LEMMA], df_separable_perfixed_words[LEMMA]),
])
# Out:
# Series([], dtype: str)

# %% [markdown]
# From the list above, the items that are in the form <i>separable_prefix + zu + infinitive</i> are also verbs.

# %%
infinitive_clause_prefixes = tuple(f"{prefix}zu" for prefix in separable_prefixes)
filter = df_separable_perfixed_words[WORD].str.startswith(infinitive_clause_prefixes)
df_infinitive_clause = df_separable_perfixed_words[filter]

# Removing them from the separable-prefixed list, so that they can be independantly analysed
df_separable_perfixed_words = drop_rows(df_separable_perfixed_words, df_infinitive_clause)

df_infinitive_clause
# Out:
#                word         lemma
# 456      aufzubauen      aufbauen
# 508     aufzunehmen     aufnehmen
# 480  auszubildenden  auszubildend
# 326   durchzuführen   durchführen
# 410     einzusetzen     einsetzen
# 256      umzusetzen      umsetzen

# %%
# auszubildenden is NOT a verb form used in infinitive-clauses
modifiers = [480]
df_modifiers = add_rows(df_modifiers, df_infinitive_clause.loc[modifiers])
df_infinitive_clause = drop_rows(df_infinitive_clause, df_infinitive_clause.loc[modifiers])

# Adding the rest to the results and removing them from infinitive-clause list
df_results = add_rows(df_results, df_infinitive_clause)

# %% [markdown]
# From the rest of the separable-prefixed list, the items that are in the form <i>separable_prefix + ge</i> may be adj/adv or Partizip II:
# <ul>
# <li>If the end in 'n' or 't' they may be Partizip II</li>
# <li>Otherwise they may be adj/adv, so they will be stored in a separate DF for further processing.</li>
# </ul>

# %%
partizip_ii_prefixes = tuple(f"{prefix}ge" for prefix in separable_prefixes)
filter = (
    (df_separable_perfixed_words[WORD].str.startswith(partizip_ii_prefixes)) &
    ((df_separable_perfixed_words[WORD].str.endswith('n')) | (df_separable_perfixed_words[WORD].str.endswith('t')))
)


# Not Partizip II:
not_df_partizip_ii = df_separable_perfixed_words[~filter]
# Adding them to the modifiers
df_modifiers = add_rows(df_modifiers, not_df_partizip_ii)
# Removing them from the separable-prefixed list
df_separable_perfixed_words = drop_rows(df_separable_perfixed_words, not_df_partizip_ii)

# Now the remaining MAY be Partizip II
df_partizip_ii = df_separable_perfixed_words[filter]
df_partizip_ii
# Out:
# /tmp/ipykernel_42104/458367691.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_partizip_ii = df_separable_perfixed_words[filter]
#                  word            lemma
# 518          abgebaut          abbauen
# 414         abgesehen          absehen
# 257        abgestimmt        abstimmen
# 381        angebracht        anbringen
# 195         angegeben          angeben
# 136       angehörigen      angehörigen
# 109       angekündigt       ankündigen
# 164        angenommen         annehmen
# 474        angeordnet         anordnen
# 123         angepasst         anpassen
# 259      angesprochen       ansprechen
# 106         angezeigt         anzeigen
# 102         aufgebaut         aufbauen
# 419      aufgefordert       auffordern
# 369        aufgeführt        aufführen
# 267        aufgehoben         aufheben
# 33        aufgenommen        aufnehmen
# 293        aufgerufen         aufrufen
# 163       aufgestellt       aufstellen
# 212         ausgebaut         ausbauen
# 486       ausgebildet        ausbilden
# 422        ausgeführt        ausführen
# 291      ausgewählten     ausgewählten
# 492         ausgelegt         auslegen
# 265         ausgelöst         auslösen
# 524       ausgenommen        ausnehmen
# 300      ausgerichtet       ausrichten
# 230        ausgesetzt        aussetzen
# 278     ausgesprochen      aussprechen
# 97       ausgestattet       ausstatten
# 395       ausgestellt       ausstellen
# 423       ausgewertet        auswerten
# 255        ausgewählt        auswählen
# 83      ausgezeichnet      auszeichnen
# 9        durchgeführt      durchführen
# 276       eingebunden        einbinden
# 143        eingeführt        einführen
# 406       eingehalten        einhalten
# 271       eingeleitet        einleiten
# 261       eingereicht       einreichen
# 21         eingesetzt        einsetzen
# 112       eingestellt       einstellen
# 523      festgehalten       festhalten
# 111      festgestellt      feststellen
# 266       fortgesetzt       fortsetzen
# 407       hingewiesen        hinweisen
# 325        mitgeteilt        mitteilen
# 314      nachgewiesen       nachweisen
# 248           umgehen          umgehen
# 59          umgesetzt         umsetzen
# 294     untergebracht     unterbringen
# 110          vorgehen         vorgehen
# 246         vorgelegt         vorlegen
# 170       vorgenommen        vornehmen
# 66         vorgesehen         vorsehen
# 247        zugelassen         zulassen
# 315   zusammengefasst  zusammengefasst
# 228  zusammengestellt  zusammenstellen
# 530        zugestimmt        zustimmen
# 269         übergeben        übergeben

# %% [markdown]
# It is noticed that in some cases, the word and lemma look alike, which in this case would mean that the supposedly Partizip II would look exactly as the infinitive, which flags that it is an adj/adv rather than a true Partizip II. But there are exceptions such as 'umgeben', so they need to be processed case by case.

# %%
df_partizip_ii_similar_word_lemma = df_partizip_ii[df_partizip_ii[WORD] == df_partizip_ii[LEMMA]]
df_partizip_ii = drop_rows(df_partizip_ii, df_partizip_ii_similar_word_lemma)
df_partizip_ii_similar_word_lemma
# Out:
#                 word            lemma
# 136      angehörigen      angehörigen
# 291     ausgewählten     ausgewählten
# 248          umgehen          umgehen
# 110         vorgehen         vorgehen
# 315  zusammengefasst  zusammengefasst
# 269        übergeben        übergeben

# %%
# Selecting the ones that are definitely not Parizip II: angehörigen, ausgewählten, and zusammengefasst
modifiers = [136, 291, 315]
df_modifiers = add_rows(df_modifiers, df_partizip_ii_similar_word_lemma.loc[modifiers])
df_partizip_ii_similar_word_lemma = drop_rows(df_partizip_ii_similar_word_lemma, df_partizip_ii_similar_word_lemma.loc[modifiers])

# Adding the rest to the results
df_results = add_rows(df_results, df_partizip_ii_similar_word_lemma)

# %%
# TODO: Checking the rest of the Partizip II candidates and then we will bedone with separable-prefixed ones.

# %% [markdown]
# ## Further filters

# %%
# The list of lemmas similar to words
df_similar_lemma_word = df[df[LEMMA] == df[WORD]]

df_similar_lemma_word
# Out:
#             word        lemma
# 411       aachen       aachen
# 264  absolvieren  absolvieren
# 478    absprache    absprache
# 282   aktivieren   aktivieren
# 440  akzeptieren  akzeptieren
# ..           ...          ...
# 408    überleben    überleben
# 28    übernehmen   übernehmen
# 166   überprüfen   überprüfen
# 70    übertragen   übertragen
# 137   überzeugen   überzeugen
#
# [195 rows x 2 columns]

# %%
# keeping the instances where word and lemma are similar, so that they will be appended to the results at the end.
expected_length = len(df) - len(df_similar_lemma_word)
df = df.drop(df_similar_lemma_word.index, axis='index')
assert len(df) == expected_length

# %%
# checking if there is an instance where the word ends in 'n' but the lemma does not
lemma_ending_in_n = df[LEMMA].str.endswith("n")
word_ending_in_n = df[WORD].str.endswith("n")

df[~lemma_ending_in_n & word_ending_in_n].to_csv(index=None)
# Out:
# 'word,lemma\nauszubildenden,auszubildend\nbauarbeiten,bauarbeit\ninteressierten,interessiert\nschwarzen,schwarze\nsteuern,steuer\nteilnehmenden,teilnehmend\nvereinten,vereint\nwurzeln,wurzel\nzahlreichen,zahlreich\nzukünftigen,zukünftig\n'

# %%
for batch in chunked(df[LEMMA].tolist(), BATCH_SIZE):
    print(', '.join(batch),'\n')
# Out:
# aachen, abbauen, absehen, absolvieren, abstimmen, aktivieren, aktualisieren, akzeptieren, analysieren, anbringen, angeben, angehörigen, ankündigen, annehmen, anordnen, anpassen, anschauen, ansprechen, antreten, anzeigen, aufbauen, auffordern, aufführen, aufheben, aufnehmen, aufrufen, aufstellen, ausbauen, ausbilden, ausfallen
#
# ausführen, ausgewählten, auslegen, auslösen, ausnehmen, ausprobieren, ausrichten, aussetzen, aussprechen, ausstatten, ausstellen, auswerten, auswählen, auszeichnen, basieren, beantragen, beantworten, bearbeiten, beauftragen, bedienen, bedürfen, beeindrucken, beeinflussen, befassen, befinden, befragen, befreien, begegnen, begeistern, begrenzen
#
# begrüßen, beinhalten, beitragen, belasten, belegen, beleuchten, bemühen, benennen, benötigen, berechnen, berechtigen, bereitstellen, bergen, berufen, beruhen, berücksichtigen, beschließen, beschränken, besitzen, besprechen, beteiligen, betonen, betreiben, betreten, betroffen, beurteilen, beweisen, bewältigen, bezeichnen, beziehen
#
# bieten, bilden, binden, darstellen, definieren, dienen, drohen, drohnen, durchführen, einbeziehen, einbinden, einbringen, einführen, einhalten, einleiten, einreichen, einsetzen, einstellen, empfangen, engagieren, entfallen, entfernen, entnehmen, entscheiden, entsprechen, entstehen, entwickeln, erarbeiten, ereignen, erfahren
#
# erfassen, erfolgen, erfordern, erheben, erhöhen, erkennen, erkunden, erlangen, erledigen, erleichtern, erleiden, erlernen, erläutern, ermitteln, ermöglichen, erneuern, errichten, erscheinen, ersetzen, erstatten, erstellen, erteilen, erweitern, erwerben, erwähnen, erzeugen, erzielen, eröffnen, etablieren, existieren
#
# fassen, festhalten, feststellen, finanzieren, fließen, fordern, formulieren, fortsetzen, fördern, führen, garantieren, gebieten, gefassen, gefährden, gefällen, gelangen, gelingen, gelten, genehmigen, genügen, geschehen, gewohnen, gewähren, gewährleisten, greifen, habben, herrschen, hinterlassen, hinweisen, holen
#
# identifizieren, inhalten, integrieren, investieren, kennzeichnen, klicken, klingen, klären, kombinieren, kommunizieren, konfrontieren, kontaktieren, konzipieren, koordinieren, kritisieren, landen, lauten, lehren, leiden, leisten, lohnen, löschen, lösen, mitteilen, nachdenken, nachweisen, nutzen, olympischen, optimieren, orientieren
#
# personenbezogen, pflegen, posten, preisen, proben, prägen, präsentieren, punkten, realisieren, reduzieren, regeln, registrieren, rollen, sanieren, scheitern, schriten, schätzen, schützen, sichern, sicherstellen, sinken, sorgen, speisen, sperren, spezialisieren, spiegeln, spüren, stammen, steigern, streichen
#
# stürzen, thematisieren, treiben, umfassen, umgehen, umsetzen, unterbringen, unterliegen, unterrichten, unterscheiden, verabschieden, verankern, verarbeiten, verbreiten, vereinen, vereinigen, verfolgen, verfügen, vergeben, verhandeln, verknüpfen, verlaufen, verlegen, verleihen, verlängern, vermeiden, vermitteln, vermögen, verpflichten, verschaffen
#
# versehen, versichern, versorgen, verstärken, verteilen, vertreiben, vertreten, verweisen, verzeichnen, verzichten, verändern, veröffentlichen, vorgehen, vorhaben, vorlegen, vorliegen, vornehmen, vorsehen, wahrnehmen, warnen, weichen, weisen, weiterentwickeln, weitergeben, wenden, werten, widmen, wussen, wünschen, zeugen
#
# zielen, zulassen, zusammenstellen, zustimmen, äußern, übergeben, überleben, übermitteln, übernehmen, überprüfen, überschreiten, übertragen, überzeugen

# %%
rows_to_drop = {
    "aachen", "angehörigen",
    "ausgewählten",
    "betroffen",
    "drohnen",
    "gefassen", "gewohnen", "gefällen", "habben",
    
    }

expected_length = len(df) - len(rows_to_drop)
df = df[~df[WORD].isin(rows_to_drop)]
assert len(df) == expected_length

# %%
df_temp = pd.read_csv(TEMP_FILE, sep=';', index_col=None, header=None)

with pd.option_context('display.max_rows', None):
    display(df_temp)
# Out:
#                       0                                  1  \
# 0                abends                     in the evening
# 1              abhängig                          dependent
# 2          abschließend                   final/concluding
# 3                 aktiv                             active
# 4               aktuell                 current/up-to-date
# 5               alleine                              alone
# 6            alternativ                        alternative
# 7          andererseits                  on the other hand
# 8               anfangs                 at first/initially
# 9             angeblich                          allegedly
# 10           angemessen               appropriate/adequate
# 11           angewiesen                  dependent/reliant
# 12            attraktiv                         attractive
# 13          aufeinander    on each other/one after another
# 14           aufmerksam                   attentive/notice
# 15         ausdrücklich                   explicit/express
# 16          auseinander                              apart
# 17          ausführlich                           detailed
# 18          ausreichend                         sufficient
# 19       ausschließlich                     exclusive/only
# 20                außen                            outside
# 21         barrierefrei                       barrier-free
# 22              bedingt                conditional/limited
# 23           begeistert                       enthusiastic
# 24              beinahe                             almost
# 25       beispielsweise                        for example
# 26               bereit                     ready/ready to
# 27              bestens              excellently/very well
# 28              bewusst               conscious/deliberate
# 29               bisher                   so far/until now
# 30              bislang                   so far/up to now
# 31           bundesweit                         nationwide
# 32              dadurch                 thereby/through it
# 33              dagegen       against it/on the other hand
# 34                daher                    therefore/hence
# 35                dahin                there/to that place
# 36             dahinter                          behind it
# 37              dankbar                           grateful
# 38            daraufhin              thereupon/as a result
# 39                darum                therefore/around it
# 40            dauerhaft                  permanent/lasting
# 41            definitiv                definite/definitely
# 42      dementsprechend                        accordingly
# 43              demnach              accordingly/therefore
# 44              denkbar              conceivable/thinkable
# 45              dennoch                       nevertheless
# 46              derweil                          meanwhile
# 47                desto  the (as in "the more...the more")
# 48      deutschlandweit                       Germany-wide
# 49                dicht                  dense/close/tight
# 50              diesmal                          this time
# 51              digital                            digital
# 52              doppelt                             double
# 53             durchaus                   quite/absolutely
# 54               ebenso                   just as/likewise
# 55             effektiv                          effective
# 56            effizient                          efficient
# 57                 egal         equal/whatever/matters not
# 58         ehrenamtlich                 voluntary/honorary
# 59               eigens               especially/expressly
# 60            eindeutig                  clear/unambiguous
# 61           einerseits                    on the one hand
# 62                einst                      once/formerly
# 63           einstimmig                          unanimous
# 64        einverstanden                agreed/in agreement
# 65       empfehlenswert                      recommendable
# 66            endgültig                    final/permanent
# 67             englisch                            English
# 68                enorm                           enormous
# 69             entfernt                     distant/remote
# 70         entscheidend                  decisive/critical
# 71         erforderlich                 necessary/required
# 72            erheblich           considerable/substantial
# 73           erhältlich                          available
# 74            erkennbar          recognizable/identifiable
# 75               erneut                      renewed/again
# 76                ernst                            serious
# 77           erreichbar               accessible/available
# 78              erstmal                      first/for now
# 79             erstmals                 for the first time
# 80            eventuell                           possibly
# 81                extra                 extra/additionally
# 82               extrem                          extremely
# 83                 fair                               fair
# 84           finanziell                          financial
# 85                  fit                                fit
# 86             flexibel                           flexible
# 87                 fort                          away/gone
# 88           frühzeitig                 early/in good time
# 89               fällig                                due
# 90       gegebenenfalls              if necessary/possibly
# 91              geltend                   valid/prevailing
# 92             generell                  general/generally
# 93             genügend                  sufficient/enough
# 94               gering                         low/slight
# 95           gesetzlich                       legal/by law
# 96             gespannt                    curious/excited
# 97              gezielt                targeted/purposeful
# 98        gleichermaßen                      equally/alike
# 99               global                             global
# 100       grundsätzlich                basic/fundamentally
# 101                 her                        hither/here
# 102              heraus                         out/out of
# 103              hervor                          forth/out
# 104        hervorragend                          excellent
# 105               heuer     this year (S. German/Austrian)
# 106               heute                              today
# 107          heutzutage                           nowadays
# 108             hierbei                     hereby/in this
# 109             hierfür                           for this
# 110              hierzu             to this/regarding this
# 111         hierzulande                    in this country
# 112           hilfreich                            helpful
# 113            hingegen          however/on the other hand
# 114               hinzu                        in addition
# 115           höchstens                            at most
# 116               ideal                              ideal
# 117            immerhin                 at least/after all
# 118               indes                  meanwhile/however
# 119         individuell                         individual
# 120          inhaltlich                  regarding content
# 121               innen                             inside
# 122        insbesondere            particularly/especially
# 123            insofern          in this respect/as far as
# 124            intensiv                          intensive
# 125        interessiert                         interested
# 126           irgendwie                            somehow
# 127            irgendwo                          somewhere
# 128           jederzeit                    any time/always
# 129              jedoch                            however
# 130             jeweils                  each/respectively
# 131            jährlich                      annual/yearly
# 132          keineswegs                        by no means
# 133            komplett                           complete
# 134             konkret                  concrete/specific
# 135          konsequent                         consistent
# 136      kontinuierlich                         continuous
# 137          kostenfrei                     free of charge
# 138            kritisch                           critical
# 139             kräftig                      strong/sturdy
# 140         kurzfristig            short-term/short-notice
# 141             künftig               future/in the future
# 142            kürzlich                           recently
# 143               lange                        long (time)
# 144         langfristig                          long-term
# 145           lediglich                        merely/only
# 146        letztendlich                         ultimately
# 147           letztlich                 finally/ultimately
# 148               links                               left
# 149                live                               live
# 150              längst                  long since/by far
# 151              massiv                      massive/solid
# 152             maximal                            maximum
# 153          maßgeblich                 decisive/primarily
# 154            mehrfach          multiple times/repeatedly
# 155              mitten                   in the middle of
# 156        mittlerweile                   meanwhile/by now
# 157            mitunter              occasionally/at times
# 158               mobil                             mobile
# 159             morgens                     in the morning
# 160      möglicherweise                           possibly
# 161           möglichst                   as...as possible
# 162         nachfolgend               following/subsequent
# 163          nachhaltig                sustainable/lasting
# 164              nachts                           at night
# 165              nahezu                      almost/nearly
# 166             negativ                           negative
# 167             niemals                              never
# 168             nochmal                              again
# 169            nochmals                  again (once more)
# 170             nunmehr                     now/henceforth
# 171             nutzbar                             usable
# 172               nötig                          necessary
# 173            offenbar                 apparently/obvious
# 174      offensichtlich                            obvious
# 175             oftmals                         frequently
# 176             ohnehin                             anyway
# 177            parallel                           parallel
# 178             perfekt                            perfect
# 179           politisch                          political
# 180             positiv                           positive
# 181          problemlos                   without problems
# 182             präsent                            present
# 183          qualitativ                        qualitative
# 184               quasi             as it were/so to speak
# 185               rasch                        quick/swift
# 186                real                               real
# 187           rechtlich                              legal
# 188              rechts                              right
# 189         rechtzeitig                            in time
# 190            regional                           regional
# 191               reich                               rich
# 192           reichlich                       plenty/ample
# 193            relevant                           relevant
# 194           scheinbar                 apparent/seemingly
# 195            schlicht                       simple/plain
# 196         schließlich                  finally/after all
# 197             seither                         since then
# 198  selbstverständlich             of course/self-evident
# 199          sicherlich                          certainly
# 200            sichtbar                            visible
# 201            sinnvoll                  meaningful/useful
# 202               smart                              smart
# 203          sorgfältig                            careful
# 204          spätestens                      at the latest
# 205             spürbar                         noticeable
# 206           staatlich                 state(-run)/public
# 207              stabil                             stable
# 208         stattdessen                            instead
# 209              stetig                  steady/continuous
# 210               stets                  always/constantly
# 211           technisch                          technical
# 212           teilweise                          partially
# 213         telefonisch                       by telephone
# 214               total                     total/complete
# 215        traditionell                        traditional
# 216         transparent                        transparent
# 217           umfassend            comprehensive/extensive
# 218            umgehend                        immediately
# 219           umgekehrt                   reverse/opposite
# 220              unklar                            unclear
# 221       unkompliziert                      uncomplicated
# 222         unmittelbar                   immediate/direct
# 223         unterdessen                          meanwhile
# 224       untereinander                   among themselves
# 225        unverzüglich          immediately/without delay
# 226         unverändert                          unchanged
# 227      verantwortlich                        responsible
# 228           verfügbar                          available
# 229     vergleichsweise                      comparatively
# 230            vermehrt                          increased
# 231          vermutlich                         presumably
# 232        verständlich                     understandable
# 233            vertraut                  familiar/intimate
# 234            vielfach              frequently/many times
# 235          vielfältig                     diverse/varied
# 236            vielmehr                        rather/more
# 237          vollkommen                   perfect/complete
# 238         vollständig                           complete
# 239         voneinander                    from each other
# 240               vorab                         in advance
# 241               voran                      ahead/forward
# 242              voraus                     ahead/in front
# 243     voraussichtlich                presumably/probably
# 244             vorerst                  for now/initially
# 245           vorhanden                 available/existing
# 246                vorn                       at the front
# 247       vorübergehend                          temporary
# 248              völlig                 completely/utterly
# 249           weiterhin             furthermore/continuing
# 250          weitgehend                  largely/extensive
# 251            weltweit                          worldwide
# 252          wesentlich            essential/significantly
# 253            wiederum            again/on the other hand
# 254             wirksam                          effective
# 255      wirtschaftlich                           economic
# 256    wissenschaftlich                         scientific
# 257               wobei                      whereby/while
# 258             wodurch              through which/by what
# 259               wofür                           for what
# 260               wohin                           where to
# 261           womöglich                     possibly/maybe
# 262         wöchentlich                             weekly
# 263            zeitlich            temporal/regarding time
# 264             zeitnah                      promptly/soon
# 265           zeitweise               temporarily/at times
# 266             zentral                            central
# 267            zugleich                   at the same time
# 268          zugänglich                         accessible
# 269             zuhause                            at home
# 270           zukünftig               future/in the future
# 271             zuletzt                       last/finally
# 272            zulässig             permissible/admissible
# 273             zumeist                             mostly
# 274           zunehmend                         increasing
# 275            zunächst             first of all/initially
# 276           zuständig                        responsible
# 277               zuvor                  before/previously
# 278            zwingend               compelling/mandatory
# 279             äußerst                          extremely
# 280               öfter                         more often
# 281        überraschend                         surprising
# 282         überwiegend                      predominantly
#
#                          2                                                  3
# 0               [ˈaːbn̩ts]  Ich bin abends immer zu Hause.<br><br>Abends g...
# 1               [ˈaphɛŋɪç]  Sie ist finanziell von ihren Eltern abhängig.<...
# 2            [ˈapʃliːsənt]  Wir können eine abschließende Bemerkung machen...
# 3                [akˈtiːf]  Meine Großmutter ist trotz ihres Alters sehr a...
# 4               [akˈtu̯ɛl]  Hast du die aktuellen Nachrichten gehört?<br><...
# 5               [aˈlaɪ̯nə]  Das kleine Kind kann noch nicht alleine einsch...
# 6           [altɛrnaˈtiːf]  Wir suchen eine alternative Lösung für das Pro...
# 7          [ˈandərɐrzaits]  Einerseits möchte ich verreisen, andererseits ...
# 8                [ˈanfaŋs]  Anfangs hatte ich große Schwierigkeiten mit de...
# 9              [ˈanɡəplɪç]  Sie ist angeblich krank, aber ich glaube es ni...
# 10           [ˈanɡəˌmɛsn̩]  Wir suchen eine angemessene Wohnung für unsere...
# 11          [ˈanɡəˌviːzn̩]  Nach dem Unfall ist er auf Hilfe angewiesen.<b...
# 12            [atʁakˈtiːf]  Sie ist eine attraktive junge Frau.<br><br>Das...
# 13         [aʊfˈʔaɪ̯nandɐ]  Die Kinder passen gut aufeinander auf.<br><br>...
# 14         [ˈaʊ̯fmɛʁkzaːm]  Die Schüler waren heute sehr aufmerksam.<br><b...
# 15          [ˈaʊ̯sdʁʏklɪç]  Ich habe es dir ausdrücklich verboten!<br><br>...
# 16          [aʊsʔaɪˈnandɐ]  Die zwei Freunde sind auseinander gegangen.<br...
# 17         [ˈaʊ̯sfyːɐ̯lɪç]  Kannst du mir das bitte ausführlich erklären?<...
# 18         [ˈaʊ̯sʁaɪ̯çn̩t]  Hast du ausreichend Geld für die Reise?<br><br...
# 19         [ˈaʊ̯sʃliːslɪç]  Dies ist ein ausschließlich für Mitglieder bes...
# 20               [ˈaʊ̯sn̩]  Die Tür öffnet sich nach außen.<br><br>Von auß...
# 21         [baˈʁiːʁəˌfʁaɪ]  Der Neubau ist komplett barrierefrei.<br><br>E...
# 22               [bəˈdɪŋt]  Meine Zustimmung ist bedingt.<br><br>Das kann ...
# 23           [bəˈɡaɪ̯stɐt]  Die Kinder waren von dem Zirkus begeistert.<br...
# 24             [ˈbaɪ̯naːə]  Ich wäre beinahe gestürzt.<br><br>Das hätte be...
# 25    [ˈbaɪ̯ʃpiːlsˌvaɪ̯zə]  Viele Tiere, beispielsweise Hunde, sind sehr t...
# 26              [bəˈʁaɪ̯t]  Ich bin bereit für die Prüfung.<br><br>Sind Si...
# 27              [ˈbɛstn̩s]  Wir haben uns bestens verstanden.<br><br>Mir g...
# 28               [bəˈvʊst]  Ihm wurde die Gefahr nicht bewusst.<br><br>Das...
# 29             [bɪsˈheːɐ̯]  Bisher hat alles gut geklappt.<br><br>Das ist ...
# 30               [bɪsˈlaŋ]  Bislang gab es keine Probleme.<br><br>Die bisl...
# 31          [ˈbʊndəsvaɪ̯t]  Die Streiks fanden bundesweit statt.<br><br>Da...
# 32              [daːˈdʊʁç]  Er trainierte viel, dadurch wurde er besser.<b...
# 33            [daːˈɡeːɡn̩]  Ich bin dagegen, dass wir jetzt gehen.<br><br>...
# 34             [daːˈheːɐ̯]  Ich denke, also bin ich – daher komme ich zu d...
# 35               [daːˈhɪn]  Der Weg dahin ist noch weit.<br><br>Meine Hoff...
# 36              [daˈhɪntɐ]  Das Haus hat einen großen Garten dahinter.<br>...
# 37            [ˈdaŋkbaːɐ̯]  Ich bin dir sehr dankbar für deine Hilfe.<br><...
# 38           [daˈʁaʊ̯fhɪn]  Er beleidigte mich, daraufhin ging ich.<br><br...
# 39               [daːˈʁʊm]  Er war krank, darum konnte er nicht kommen.<br...
# 40            [ˈdaʊ̯ɐhaft]  Wir suchen eine dauerhafte Lösung.<br><br>Das ...
# 41           [definiˈtiːf]  Das ist eine definitive Zusage.<br><br>Das wer...
# 42     [ˈdeːməntˌʃpʁɛçn̩t]  Er hat viel gearbeitet und dementsprechend war...
# 43             [ˈdeːmnaːx]  Es hat geregnet, demnach ist die Straße nass.<...
# 44            [ˈdɛŋkbaːɐ̯]  Es ist durchaus denkbar, dass er Recht hat.<br...
# 45                [ˈdɛnɔx]  Es regnete, dennoch gingen wir spazieren.<br><...
# 46            [deːɐ̯ˈvaɪl]  Ich koche, du kannst derweil den Tisch decken....
# 47                [ˈdɛsto]  Je mehr man übt, desto besser wird man.<br><br...
# 48      [ˈdɔɪ̯t͡ʃlantvaɪt]  Das Unternehmen sucht deutschlandweit nach Mit...
# 49                  [dɪçt]  Der Wald ist sehr dicht.<br><br>Bleib dicht hi...
# 50             [ˈdiːsmaːl]  Diesmal klappt es bestimmt!<br><br>Wer ist die...
# 51             [diɡiˈtaːl]  Wir leben in einer digitalen Welt.<br><br>Das ...
# 52               [ˈdɔpl̩t]  Ich habe das doppelte bezahlt.<br><br>Sieh lie...
# 53            [dʊʁçˈʔaʊ̯s]  Das ist durchaus möglich.<br><br>Ich finde das...
# 54             [ˈeːbn̩zoː]  Er ist ebenso groß wie sein Bruder.<br><br>Ich...
# 55             [ɛfɛkˈtiːf]  Das ist eine sehr effektive Methode.<br><br>Wi...
# 56          [ɛfiˈt͡si̯ɛnt]  Die Maschine arbeitet sehr effizient.<br><br>E...
# 57                [eˈɡaːl]  Das ist mir völlig egal!<br><br>Egal was passi...
# 58        [ˈeːʁənˌʔamtlɪç]  Sie arbeitet ehrenamtlich im Tierheim.<br><br>...
# 59              [ˈaɪ̯ɡn̩s]  Ich bin eigens dafür angereist.<br><br>Das hab...
# 60          [ˈaɪ̯ndɔɪ̯tɪç]  Die Antwort war eindeutig falsch.<br><br>Das i...
# 61          [ˈaɪ̯nɐzaɪ̯ts]  Einerseits möchte ich die Stelle, andererseits...
# 62                [aɪ̯nst]  Einst war diese Gegend ein dichter Wald.<br><b...
# 63           [ˈaɪ̯nʃtɪmɪç]  Der Beschluss wurde einstimmig gefasst.<br><br...
# 64      [ˈaɪ̯nfɛɐ̯ʃtandn̩]  Ich bin mit deinem Vorschlag einverstanden.<br...
# 65   [ɛmˈp͡feːlənsˌveːɐ̯t]  Dieses Restaurant ist sehr empfehlenswert.<br>...
# 66            [ˈɛntɡʏltɪç]  Das ist meine endgültige Entscheidung.<br><br>...
# 67                [ˈɛŋlɪʃ]  Er spricht fließend englisch.<br><br>Das ist e...
# 68                [eˈnɔʁm]  Der Lärm war enorm.<br><br>Die Kosten sind eno...
# 69             [ɛntˈfɛʁnt]  Sie wohnen weit entfernt von hier.<br><br>Ich ...
# 70          [ɛntˈʃaɪ̯dn̩t]  Das war der entscheidende Moment.<br><br>Entsc...
# 71        [ɛɐ̯ˈfoːɐ̯dɐlɪç]  Alle erforderlichen Unterlagen liegen vor.<br>...
# 72           [ɛɐ̯ˈheːplɪç]  Es gab erhebliche Probleme.<br><br>Der Schaden...
# 73           [ɛɐ̯ˈhɛltlɪç]  Das Produkt ist überall erhältlich.<br><br>Die...
# 74          [ɛɐ̯ˈkɛnbaːɐ̯]  Das Muster ist deutlich erkennbar.<br><br>Sein...
# 75             [ɛɐ̯ˈnɔɪ̯t]  Wir müssen einen erneuten Versuch starten.<br>...
# 76                 [ɛʁnst]  Mach dir keine Sorgen, das ist nicht so ernst ...
# 77        [ɛɐ̯ˈʁaɪ̯çbaːɐ̯]  Der Chef ist telefonisch nicht erreichbar.<br>...
# 78           [ˈeːɐ̯stmaːl]  Das machen wir erstmal so.<br><br>Ich muss ers...
# 79          [ˈeːɐ̯stmaːls]  Er ist erstmals Vater geworden.<br><br>Das Kon...
# 80             [evɛntuˈɛl]  Ich komme eventuell etwas später.<br><br>Das i...
# 81               [ˈɛkstʁa]  Das gibt es extra dazu.<br><br>Ich bin extra f...
# 82             [ɛksˈtʁeːm]  Das Wetter ist heute extrem kalt.<br><br>Er is...
# 83                 [fɛːɐ̯]  Das war kein fairer Wettkampf.<br><br>Sie hat ...
# 84         [finanˈt͡si̯ɛl]  Wir stecken in finanziellen Schwierigkeiten.<b...
# 85                   [fɪt]  Ich versuche, mich fit zu halten.<br><br>Für d...
# 86           [flɛˈksiːbl̩]  Meine Arbeitszeiten sind sehr flexibel.<br><br...
# 87                  [fɔʁt]  Er ist schon lange fort von hier.<br><br>Und s...
# 88        [ˈfʁyːt͡saɪ̯tɪç]  Wir müssen frühzeitig mit den Vorbereitungen b...
# 89                [ˈfɛlɪç]  Die Rechnung ist morgen fällig.<br><br>Eine Re...
# 90       [ɡəˈɡeːbənənfals]  Gegebenenfalls müssen wir den Termin verschieb...
# 91              [ˈɡɛltn̩t]  Das ist ein geltendes Gesetz.<br><br>Er konnte...
# 92              [ɡenəˈʁɛl]  Das ist eine generelle Regel.<br><br>Generell ...
# 93            [ɡəˈnyːɡn̩t]  Hast du genügend Schlaf bekommen?<br><br>Dafür...
# 94                [ɡəˈʁɪŋ]  Die Chancen sind gering.<br><br>Er hat nur ein...
# 95           [ɡəˈzɛt͡slɪç]  Dazu bin ich gesetzlich verpflichtet.<br><br>D...
# 96              [ɡəˈʃpant]  Ich bin gespannt, was passiert.<br><br>Wir sin...
# 97            [ɡəˈt͡siːlt]  Das war eine gezielte Aktion.<br><br>Er hat ge...
# 98        [ˈɡlaɪ̯çɐmaːsn̩]  Das betrifft alle gleichermaßen.<br><br>Er ist...
# 99              [ɡloˈbaːl]  Das ist ein globales Problem.<br><br>Wir müsse...
# 100       [ˈɡʁʊntˌz̥ɛtlɪç]  Ich stimme dir grundsätzlich zu.<br><br>Das is...
# 101                [heːɐ̯]   Komm her zu mir!<br><br>Das ist schon lange her.
# 102             [hɛˈʁaʊ̯s]  Komm endlich aus deinem Zimmer heraus!<br><br>...
# 103           [hɛɐ̯ˈfoːɐ̯]  Sie trat aus dem Schatten hervor.<br><br>Seine...
# 104    [hɛɐ̯ˈfoːɐ̯ʁaːɡn̩t]  Das Essen war hervorragend.<br><br>Sie hat ein...
# 105               [ˈhɔɪ̯ɐ]  Heuer haben wir einen milden Winter.<br><br>Di...
# 106              [ˈhɔɪ̯tə]  Heute ist ein schöner Tag.<br><br>Das mache ic...
# 107      [ˈhɔɪ̯t͡suˌtaːɡə]  Heutzutage hat fast jeder ein Smartphone.<br><...
# 108           [hiːɐ̯ˈbaɪ̯]  Hierbei handelt es sich um einen Irrtum.<br><b...
# 109          [hiːɐ̯ˈfyːɐ̯]  Ich habe hierfür kein Verständnis.<br><br>Hier...
# 110          [hiːɐ̯ˈt͡suː]  Hierzu möchte ich etwas sagen.<br><br>Hierzu f...
# 111      [hiːɐ̯t͡suˈlandə]  Hierzulande isst man gerne Brot.<br><br>Das is...
# 112           [ˈhɪlfʁaɪ̯ç]  Dein Rat war sehr hilfreich.<br><br>Das wäre e...
# 113           [ˈhɪnɡeːɡn̩]  Er ist laut, sein Bruder hingegen ist ruhig.<b...
# 114            [hɪnˈt͡suː]  Es kommt noch ein weiterer Punkt hinzu.<br><br...
# 115           [ˈhøːçstn̥s]  Das dauert höchstens eine Stunde.<br><br>Du da...
# 116              [ideˈaːl]  Das Wetter ist ideal zum Wandern.<br><br>Sie i...
# 117              [ˈɪmɐhɪn]  Immerhin hast du es versucht.<br><br>Er ist im...
# 118               [ˈɪndəs]  Er schlief, ich las indes.<br><br>Sie versprac...
# 119          [ɪndividuˈɛl]  Jeder Mensch hat individuelle Bedürfnisse.<br>...
# 120           [ˈɪnhaltlɪç]  Inhaltlich war der Vortrag sehr gut.<br><br>Es...
# 121                [ˈɪnən]  Die Tür lässt sich von innen öffnen.<br><br>Vo...
# 122        [ɪnsbəˈzɔndɛʁə]  Ich mag Tiere, insbesondere Hunde.<br><br>Insb...
# 123            [ɪnzoˈfɛʁn]  Insofern hast du Recht.<br><br>Er hat viel Erf...
# 124           [ɪntɛnˈziːf]  Die beiden pflegen einen intensiven Kontakt.<b...
# 125        [ɪntəˈʁɛsiːɐ̯t]  Sie ist sehr interessiert an Kunst.<br><br>Er ...
# 126           [ˈɪʁɡn̩tviː]  Das schaffen wir irgendwie schon.<br><br>Irgen...
# 127           [ˈɪʁɡn̩tvoː]  Ich habe meine Schlüssel irgendwo verloren.<br...
# 128        [ˈjeːdɐt͡saɪ̯t]  Du kannst mich jederzeit anrufen.<br><br>Das w...
# 129              [jeːˈdɔx]  Er ist krank, jedoch arbeitet er weiter.<br><b...
# 130            [ˈjeːvaɪls]  Die Getränke kosten jeweils zwei Euro.<br><br>...
# 131            [ˈjɛːɐ̯lɪç]  Der Verein hat jährlich eine Versammlung.<br><...
# 132       [ˈkaɪ̯nəsˌveːks]  Das ist keineswegs sicher.<br><br>Ich bin kein...
# 133             [kɔmˈplɛt]  Die Wohnung ist komplett möbliert.<br><br>Das ...
# 134            [kɔnˈkʁeːt]  Kannst du mir ein konkretes Beispiel nennen?<b...
# 135          [kɔnzeˈkvɛnt]  Er ist ein sehr konsequenter Mensch.<br><br>Si...
# 136      [kɔntinuˈiːɐ̯lɪç]  Die Preise steigen kontinuierlich.<br><br>Eine...
# 137         [ˈkɔstn̩fʁaɪ̯]  Der Versand ist kostenfrei.<br><br>Sie erhalte...
# 138             [ˈkʁiːtɪʃ]  Die Lage ist kritisch.<br><br>Er betrachtete d...
# 139             [ˈkʁɛftɪç]  Er ist ein kräftiger Mann.<br><br>Sie hat kräf...
# 140       [ˈkʊʁt͡sfʁɪstɪç]  Das ist nur eine kurzfristige Lösung.<br><br>K...
# 141             [ˈkʏnftɪç]  Unsere künftigen Pläne sind noch geheim.<br><b...
# 142           [ˈkʏʁt͡slɪç]  Ich habe ihn kürzlich getroffen.<br><br>Das wa...
# 143                [ˈlaŋə]  Das dauert noch lange.<br><br>Ich habe lange a...
# 144          [ˈlaŋfʁɪstɪç]  Wir setzen auf eine langfristige Partnerschaft...
# 145           [ˈleːdɪklɪç]  Ich habe lediglich gefragt.<br><br>Das war led...
# 146       [ˈlɛt͡stʔɛntlɪç]  Letztendlich hat er doch Recht behalten.<br><b...
# 147           [ˈlɛt͡stlɪç]  Letztlich kommt es auf dich an.<br><br>Das ist...
# 148                [lɪŋks]  Biegen Sie an der Ampel links ab.<br><br>Das H...
# 149                [laɪ̯f]  Das Konzert wird live übertragen.<br><br>Wir h...
# 150                [lɛŋst]  Das habe ich längst erledigt.<br><br>Das ist l...
# 151              [maˈsiːf]  Das Haus hat massive Mauern.<br><br>Er wurde m...
# 152           [maksiˈmaːl]  Das Gepäck darf maximal 20 kg wiegen.<br><br>W...
# 153         [ˈmaːsɡeːplɪç]  Er war maßgeblich am Erfolg beteiligt.<br><br>...
# 154            [ˈmeːɐ̯fax]  Ich habe ihn mehrfach ermahnt.<br><br>Das ist ...
# 155               [ˈmɪtn̩]  Das Kind stand mitten auf der Straße.<br><br>M...
# 156          [ˈmɪtlɐvaɪlə]  Mittlerweile ist es dunkel geworden.<br><br>Er...
# 157             [mɪtˈʊntɐ]  Mitunter regnet es hier wochenlang nicht.<br><...
# 158              [moˈbiːl]  Ich bin mit dem Handy mobil erreichbar.<br><br...
# 159             [ˈmɔʁɡn̩s]  Morgens trinke ich immer Kaffee.<br><br>Ich st...
# 160       [ˈmøːklɪçɐvaɪzə]  Er kommt möglicherweise zu spät.<br><br>Das is...
# 161           [ˈmøːklɪçst]  Komm möglichst bald!<br><br>Wir wollen möglich...
# 162       [ˈnaːxˌfoːlɡn̩t]  Die nachfolgenden Informationen sind wichtig.<...
# 163          [ˈnaːxhaltɪç]  Wir setzen auf nachhaltige Energie.<br><br>Das...
# 164               [naxt͡s]  Nachts schlafen die meisten Menschen.<br><br>I...
# 165           [ˈnaːət͡suː]  Das ist nahezu unmöglich.<br><br>Die Arbeit is...
# 166           [ˈneːɡatiːf]  Die Antwort war negativ.<br><br>Das wirkt sich...
# 167            [ˈniːmaːls]  Das werde ich niemals vergessen.<br><br>Niemal...
# 168             [ˈnɔxmaːl]  Kannst du das nochmal sagen?<br><br>Ich versuc...
# 169            [ˈnɔxmaːls]  Ich möchte mich nochmals bedanken.<br><br>Noch...
# 170           [ˈnuːnmeːɐ̯]  Nunmehr ist alles anders.<br><br>Er ist nunmeh...
# 171          [ˈnʊt͡sbaːɐ̯]  Der Garten ist ganzjährig nutzbar.<br><br>Die ...
# 172              [ˈnøːtɪç]  Hast du alles Nötige eingepackt?<br><br>Das is...
# 173           [ˈɔfn̩baːɐ̯]  Er ist offenbar krank.<br><br>Das ist ein offe...
# 174        [ˈɔfn̩ˌzɪçtlɪç]  Das ist ein offensichtlicher Fehler.<br><br>Si...
# 175            [ˈɔftmaːls]  Oftmals ist es besser zu schweigen.<br><br>Das...
# 176             [oːnəˈhɪn]  Das wollte ich ohnehin machen.<br><br>Es ist o...
# 177            [paʁaˈleːl]  Die Straßen verlaufen parallel zueinander.<br>...
# 178             [pɛʁˈfɛkt]  Das Wetter war perfekt.<br><br>Er spricht perf...
# 179            [poˈliːtɪʃ]  Das ist eine politische Entscheidung.<br><br>S...
# 180           [ˈpoːzitiːf]  Die Rückmeldung war positiv.<br><br>Denk einfa...
# 181       [pʁoˈbleːmˌloːs]  Das lässt sich problemlos lösen.<br><br>Der Ei...
# 182             [pʁɛˈzɛnt]  Bei der Besprechung waren alle Teammitglieder ...
# 183         [kvɑliˈtɑːtɪf]  Das Produkt hat qualitative Mängel.<br><br>Qua...
# 184              [ˈkvaːzi]  Er ist quasi mein bester Freund.<br><br>Das is...
# 185                  [ʀaʃ]  Eine rasche Lösung ist gefragt.<br><br>Er ging...
# 186               [ʀeˈaːl]  Das ist keine reale Gefahr.<br><br>Ich habe mi...
# 187             [ˈʀɛçtlɪç]  Das ist rechtlich nicht erlaubt.<br><br>Wir mü...
# 188                [ʀɛçts]  Hier musst du rechts abbiegen.<br><br>Das Rath...
# 189      [ˈʀɛçtˌt͡saɪ̯tɪç]  Bist du rechtzeitig angekommen?<br><br>Wir müs...
# 190          [ʀeɡi̯oˈnaːl]  Wir kaufen regionale Produkte.<br><br>Das ist ...
# 191                [ʀaɪ̯ç]  Er ist ein reicher Mann.<br><br>Der Wald ist r...
# 192            [ˈʀaɪ̯çlɪç]  Es gab reichlich zu essen.<br><br>Wir haben no...
# 193            [ʀeleˈvant]  Das ist ein relevanter Punkt.<br><br>Diese Inf...
# 194          [ˈʃaɪ̯nbaːɐ̯]  Das ist nur ein scheinbarer Widerspruch.<br><b...
# 195                [ʃlɪçt]  Das ist eine schlichte, aber elegante Lösung.<...
# 196            [ˈʃliːslɪç]  Schließlich haben wir uns doch noch geeinigt.<...
# 197          [zaɪ̯tˈheːɐ̯]  Ich habe ihn seither nicht mehr gesehen.<br><b...
# 198  [zɛlpstfɛɐ̯ˈʃtɛntlɪç]  Das ist für mich selbstverständlich.<br><br>Se...
# 199             [ˈzɪçɐlɪç]  Das wird er sicherlich schaffen.<br><br>Sicher...
# 200           [ˈzɪçtbaːɐ̯]  Der Fortschritt ist deutlich sichtbar.<br><br>...
# 201              [ˈzɪnfɔl]  Das ist eine sinnvolle Idee.<br><br>Es ist sin...
# 202              [smaːɐ̯t]  Er trägt einen smarten Anzug.<br><br>Das war e...
# 203          [ˈzɔʁkfɛltɪç]  Er hat die Arbeit sorgfältig erledigt.<br><br>...
# 204         [ˈʃpɛːtəstn̩s]  Ich bin spätestens um acht Uhr zu Hause.<br><b...
# 205         [ˈʃpyːɐ̯baːɐ̯]  Die Entspannung war deutlich spürbar.<br><br>D...
# 206            [ˈʃtaːtlɪç]  Er arbeitet bei einer staatlichen Behörde.<br>...
# 207             [ʃtaˈbiːl]  Das Gerüst steht stabil.<br><br>Sein Gesundhei...
# 208           [ʃtatˈdɛsn̩]  Ich trinke keinen Kaffee, sondern Tee stattdes...
# 209             [ˈʃteːtɪç]  Die Preise steigen stetig.<br><br>Es gibt eine...
# 210              [ʃteːt͡s]  Ich bin stets für dich da.<br><br>Er handelt s...
# 211              [ˈtɛçnɪʃ]  Das Gerät hat einen technischen Defekt.<br><br...
# 212         [ˈtaɪ̯lvaɪ̯zə]  Die Arbeit ist teilweise schon erledigt.<br><b...
# 213          [teləˈfoːnɪʃ]  Die Bestellung kann telefonisch erfolgen.<br><...
# 214              [toˈtaːl]  Das war ein totaler Reinfall.<br><br>Ich bin t...
# 215     [tʁadiˈt͡si̯oːnɛl]  Das ist ein traditionelles Fest.<br><br>Wir fe...
# 216         [tʁansˈpaʁənt]  Die Firma sollte transparenter arbeiten.<br><b...
# 217            [ʊmˈfasn̩t]  Wir bieten eine umfassende Beratung an.<br><br...
# 218            [ˈʊmɡeːənt]  Bitte erledigen Sie das umgehend.<br><br>Er re...
# 219          [ˈʊmɡəkeːɐ̯t]  Es ist genau umgekehrt.<br><br>In umgekehrter ...
# 220           [ˈʊnˌklaːɐ̯]  Die Lage ist noch unklar.<br><br>Mir ist unkla...
# 221   [ˈʊnkɔmpliˌt͡siːɐ̯t]  Das ist ein sehr unkomplizierter Vorgang.<br><...
# 222        [ˈʊnmɪtl̩baːɐ̯]  Die Auswirkungen sind unmittelbar spürbar.<br>...
# 223           [ʊntɐˈdɛsn̩]  Ich kochte, unterdessen deckte sie den Tisch.<...
# 224        [ʊntɐʔaɪˈnandɐ]  Die Schüler haben sich untereinander geeinigt....
# 225     [ˈʊnfɛɐ̯t͡syːklɪç]  Bitte kommen Sie unverzüglich in mein Büro.<br...
# 226        [ˈʊnfɛɐ̯ʔɛndɐt]  Die Situation ist unverändert.<br><br>Das Prod...
# 227     [fɛɐ̯ˈʔantvɔʁtlɪç]  Wer ist für diesen Fehler verantwortlich?<br><...
# 228       [fɛɐ̯ˈfyːkbaːɐ̯]  Das Produkt ist nicht mehr verfügbar.<br><br>W...
# 229  [fɛɐ̯ˈɡlaɪ̯çsˌvaɪ̯zə]  Das Auto ist vergleichsweise günstig.<br><br>V...
# 230          [fɛɐ̯ˈmeːɐ̯t]  In letzter Zeit treten vermehrt Probleme auf.<...
# 231         [fɛɐ̯ˈmuːtlɪç]  Er ist vermutlich schon zu Hause.<br><br>Das i...
# 232        [fɛɐ̯ˈʃtɛntlɪç]  Kannst du das verständlich erklären?<br><br>Se...
# 233          [fɛɐ̯ˈtʁaʊ̯t]  Mir ist diese Gegend vertraut.<br><br>Sie sind...
# 234             [ˈfiːlfax]  Das wurde vielfach bewiesen.<br><br>Sie ist ei...
# 235          [ˈfiːlfɛltɪç]  Das Angebot ist sehr vielfältig.<br><br>Die Na...
# 236           [ˈfiːlmeːɐ̯]  Er ist nicht dumm, vielmehr ist er faul.<br><b...
# 237            [ˈfɔlkɔmən]  Das Wetter war vollkommen.<br><br>Ich bin voll...
# 238          [ˈfɔlʃtɛndɪç]  Die Liste ist vollständig.<br><br>Bitte füllen...
# 239         [fɔnʔaɪˈnandɐ]  Sie können viel voneinander lernen.<br><br>Die...
# 240            [foːɐ̯ˈʔap]  Ich möchte mich vorab für Ihre Hilfe bedanken....
# 241               [foˈʁan]  Geh du schon voran, ich komme nach.<br><br>Mit...
# 242              [foˈʁaʊs]  Er ist uns allen weit voraus.<br><br>Im Voraus...
# 243      [foˈʁaʊ̯szɪçtlɪç]  Die Ankunft ist voraussichtlich um 20 Uhr.<br>...
# 244        [foːɐ̯ˈʔeːɐ̯st]  Vorerst bleiben wir noch hier.<br><br>Das Proj...
# 245         [foːɐ̯ˈhandn̩]  Sind noch Karten vorhanden?<br><br>Die notwend...
# 246                 [fɔʁn]  Bitte setzen Sie sich nach vorn.<br><br>Er sta...
# 247       [foˈʁyːbɐɡeːənt]  Das ist nur eine vorübergehende Lösung.<br><br...
# 248               [ˈfœlɪç]  Das ist völliger Unsinn.<br><br>Ich bin völlig...
# 249            [ˈvaɪtɐhɪn]  Wir werden weiterhin zusammenarbeiten.<br><br>...
# 250          [ˈvaɪtɡeːənt]  Die Arbeit ist weitgehend erledigt.<br><br>Wir...
# 251            [ˈvɛltvaɪt]  Das Unternehmen ist weltweit tätig.<br><br>Das...
# 252          [ˈveːzn̩tlɪç]  Das ist ein wesentlicher Unterschied.<br><br>D...
# 253            [ˈviːdəʁʊm]  Er hat wiederum gelogen.<br><br>Das eine ist t...
# 254            [ˈvɪʁkzaːm]  Das Medikament ist sehr wirksam.<br><br>Wir mü...
# 255         [ˈvɪʁtʃaftlɪç]  Die Lage ist wirtschaftlich schwierig.<br><br>...
# 256        [ˈvɪsn̩ʃaftlɪç]  Das ist wissenschaftlich belegt.<br><br>Er arb...
# 257              [voˈbaɪ̯]  Wobei kann ich dir helfen?<br><br>Er erzählte ...
# 258              [voˈdʊʁç]  Wodurch hat sich das Problem ergeben?<br><br>D...
# 259             [voˈfyːɐ̯]  Wofür interessierst du dich?<br><br>Das ist da...
# 260               [voˈhɪn]  Wohin gehst du?<br><br>Das ist der Ort, wohin ...
# 261          [voːˈmøːklɪç]  Er ist womöglich schon abgereist.<br><br>Das k...
# 262           [ˈvœçn̩tlɪç]  Die Zeitschrift erscheint wöchentlich.<br><br>...
# 263          [ˈt͡saɪ̯tlɪç]  Die zeitliche Planung ist eng.<br><br>Zeitlich...
# 264          [ˈt͡saɪ̯tnaː]  Bitte bearbeiten Sie den Auftrag zeitnah.<br><...
# 265       [ˈt͡saɪ̯tvaɪ̯zə]  Die Maschine war zeitweise außer Betrieb.<br><...
# 266          [t͡sɛnˈtʁaːl]  Das ist eine zentrale Frage.<br><br>Die Wohnun...
# 267         [ˈt͡suːɡlaɪ̯ç]  Er ist Vater und Lehrer zugleich.<br><br>Sie l...
# 268         [ˈt͡suːɡɛŋlɪç]  Der Garten ist für Besucher zugänglich.<br><br...
# 269          [t͡suˈhaʊ̯zə]  Ich fühle mich hier sehr zuhause.<br><br>Bist ...
# 270        [ˈt͡suːkʏnftɪç]  Unsere zukünftigen Pläne sind noch geheim.<br>...
# 271          [t͡suˈlɛt͡st]  Zuletzt möchte ich mich bei allen bedanken.<br...
# 272          [ˈt͡suːlɛsɪç]  Das ist nach den Regeln nicht zulässig.<br><br...
# 273          [t͡suˈmaɪ̯st]  Zumeist ist das Wetter hier schön.<br><br>Die ...
# 274        [ˈt͡suːneːmənt]  Das Interesse daran ist zunehmend.<br><br>Es w...
# 275          [t͡suˈnɛːçst]  Zunächst müssen wir die Lage analysieren.<br><...
# 276        [ˈt͡suːʃtɛndɪç]  Wer ist für die Bearbeitung zuständig?<br><br>...
# 277           [t͡suˈfoːɐ̯]  Ich hatte ihn noch nie zuvor gesehen.<br><br>E...
# 278           [ˈt͡svɪŋənt]  Das ist eine zwingende Voraussetzung.<br><br>D...
# 279             [ˈɔɪ̯sɐst]  Das ist äußerst gefährlich.<br><br>Sie war äuß...
# 280                [ˈœftɐ]  Ich sollte öfter Sport treiben.<br><br>Wir seh...
# 281          [yːbɐˈʁaʃn̩t]  Das war eine überraschende Wende.<br><br>Er ka...
# 282         [ˈyːbɐviːɡn̩t]  Die Bevölkerung ist überwiegend deutschsprachi...

# %%
assert len(df) == len(df_temp)

# %% [markdown]
# # Output

# %%
df_temp[IS_HIGHFREQUENCY] = IS_HIGHFREQUENCY_VALUE
df_temp.to_csv(OUTPUT_FILE, sep='\t', header=None, index=None)
